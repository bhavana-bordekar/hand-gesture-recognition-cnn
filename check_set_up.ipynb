# %%
import sys
print(f"✅ Python: {sys.executable}")

import numpy as np
print(f"✅ NumPy: {np.__version__}")

import matplotlib.pyplot as plt
print(f"✅ Matplotlib ready!")

from PIL import Image
print(f"✅ Pillow ready!")

import cv2
print(f"✅ OpenCV: {cv2.__version__}")

import tensorflow as tf
print(f"✅ TensorFlow: {tf.__version__}")

print("EVERYTHING WORKING!")
print("Let's build our CNN!")
# Out:
# ✅ Python: /Users/apple/Desktop/Protfolio_project_CNN/myenv/bin/python
# ✅ NumPy: 1.23.5
# ✅ Matplotlib ready!
# ✅ Pillow ready!
# ✅ OpenCV: 4.11.0
# ✅ TensorFlow: 2.12.0
# EVERYTHING WORKING!
# Let's build our CNN!
